# %% [markdown]
# # Friend Introduction

# %% [markdown]
# Introducing a friend via Jupyter Notebook using the Markdown Template

# %%
first_name = input("Enter your first name: ")
Enter your first name: Oli
# Out:
#   File "<ipython-input-2-d8ac9eb0a4c3>", line 2
#     Enter your first name: Oli
#           ^
# SyntaxError: invalid syntax

# %%
name = input("Please type your name: ")
print("Hello", name)
# Out:
# Please type your name: Oli
# Hello Oli

# %%
def person():
# Out:
#   File "<ipython-input-4-8218ee94a3c0>", line 1
#     def person():
#                  ^
# SyntaxError: unexpected EOF while parsing

# %%
def person_name():
    name = input("please type your name: ")
    print("Hello", name)
    return name

person_name()
# Out:
# please type your name: Oli
# Hello Oli
# 'Oli'

# %%
### Friends Photo

![Oli in Action](https://github.com/DarkSlideRider/IronMarcus/blob/main/All%20Pics%20vom%20Samsung%20Handy%20Nov15%20017.jpg)
# Out:
# Der Befehl "[Oli" ist entweder falsch geschrieben oder
# konnte nicht gefunden werden.

# %% [markdown]
# ### Friends Photo
#
# ![Oli in Action](https://github.com/DarkSlideRider/IronMarcus/blob/main/All%20Pics%20vom%20Samsung%20Handy%20Nov15%20017.jpg)

# %% [markdown]
# ### Friend Photo
#
# ![All%20Pics%20vom%20Samsung%20Handy%20Nov15%20017.jpg](attachment:All%20Pics%20vom%20Samsung%20Handy%20Nov15%20017.jpg)

# %%
def holiday_destination ():
    destination = input("where do you go?: ")
    print("Going to", destination)
    return destination

holiday_destination ()
# Out:
# where do you go?: Ibiza
# Going to Ibiza
# 'Ibiza'

# %%
holiday_destination ()
# Out:
# where do you go?: Male
# Going to Male
# 'Male'

# %% [markdown]
# ### Photo Ibiza
#
# ![Screenshot%20Ibiza%2009.08.21.PNG](attachment:Screenshot%20Ibiza%2009.08.21.PNG)

# %% [markdown]
# ### Favourite Things to do in Ibiza for Oli
#
# - Eating
# - Drinking
# - Sleeping in the Sun

# %% [markdown]
# ### Favourite things to do in Ibiza for Oli
#
# *- Eating*
# *- Drinking*
# *- Sleeping in the Sun*

# %% [markdown]
# ### Favourite things to do in Ibiza for Oli
#
# *Eating*
# *Drinking*
# *Sleeping in the Sun*

# %% [markdown]
# ### Favourite things to do in Ibiza for Oli
#
# *- Eating*
#
# *- Drinking*
#
# *- Sleeping in the Sun*

# %% [markdown]
# ### Link Ibiza
#
# [Ibiza Video](https://www.youtube.com/watch?v=rV4B8prZ_w0)

# %% [markdown]
# ### Comment to Last (regular) Exercise
#
# **Unfortunately dont know what an annotation is, hence could not complete this piece**
