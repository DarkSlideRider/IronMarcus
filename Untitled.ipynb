# %% [markdown]
# # Idea for a website introducing a friend and asking for holiday plans

# %% [markdown]
# Purpose of this notebook is to display an idea for a webpage that shows explains about a friend's (in this case Alfred aka Fredo) favourite holiday adventure. It should interact with the user.

# %%
def person_name():
    name = input('Please type your name: ')
    print('Hello', name, 'welcome!')
    return name
name = person_name()
# Out:
# Please type your name: Fredo
# Hello Fredo

# %% [markdown]
# ### Fredo having fun preparing a barbecue:
#
# ![All%20Pics%20vom%20Samsung%20Handy%20Nov15%20017.jpg](attachment:All%20Pics%20vom%20Samsung%20Handy%20Nov15%20017.jpg)

# %%
def holiday():
    
    activity = input('What do you prefer: mountain or beach? Please type in either mountain or beach.')
    if activity == 'mountain':
                     print(name, 'your destination could be the Alps to go hiking and climbing')
    elif activity == 'beach':
                     print(name, 'your destination could be the coast of Spain to go swimming and surfing')
    else:             
    print('Please type in either mountain or beach.')
# Out:
#   File "<ipython-input-5-54046f3a44d1>", line 9
#     print('Please type in either mountain or beach.')
#     ^
# IndentationError: expected an indented block
